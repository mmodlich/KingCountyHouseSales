# %% [markdown]
# # Exploratory Data Analysis (EDA) - Capstone Two - King County House Sales

# %%
# Import required python libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load 'kc_house_data.csv'
df = pd.read_csv('/Users/mitchmodlich/Desktop/Springboard_Data_Science/Springboard/KingCountyHouseSales/data/raw/kc_house_data.csv')

# %%
# Shape of DataFrame df
df.shape
# Out:
# (21613, 21)

# %%
# Basic summary of df 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# - There are 20 columns (features) other than id.
# - None of the features have null values.

# %% [markdown]
# ## Data Distribution

# %%
# Generate descriptive statistics for numeric variables
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# - Bedrooms has a probable outlier of 33.
# - sqft_lot has a very large range with the max value being 2 orders of magnitude larger than the 75th percentile.

# %%
# Set Seaborn context to 'notebook'
sns.set_context('notebook')

# %%
# Plot price histogram
_ = sns.histplot(data=df, x='price')
plt.show()

# %%
# Create boxplot for price
_ = sns.boxplot(x='price', data=df)
plt.show()

# %% [markdown]
# - price has a right-skewed distribution with a long tail.
# - price has many values outside of 1.5 * IQR. Some values are extreme outliers.

# %%
# Plot sqft_living histogram
_ = sns.histplot(data=df, x='sqft_living')
plt.show()

# %%
# Create boxplot for sqft_living
_ = sns.boxplot(x='sqft_living', data=df)
plt.show()

# %% [markdown]
# - sqft_living has a right-skewed distribution with a long tail.
# - sqft_living has many values outside of 1.5 * IQR. Some values are extreme outliers.

# %%
# Plot sqft_living15 histogram
_ = sns.histplot(data=df, x='sqft_living15')
plt.show()

# %%
# Create boxplot for sqft_living15
_ = sns.boxplot(x='sqft_living15', data=df)
plt.show()

# %% [markdown]
# - sqft_living15 right-skewed.
# - sqft_living15 has a wider IQR and a shorter tail than sqft_living. This is intuitive as each value is an average of its 15 nearest neighbors geographically.

# %%
# Plot sqft_lot histogram
_ = sns.histplot(data=df, x='sqft_lot')
plt.show()

# %% [markdown]
# sqft_lot has an extremely long tail and is right-skewed.

# %%
# Plot sqft_lot histogram limited to 99th percentile
_ = sns.histplot(data=df, x='sqft_lot')
plt.xlim(0,np.percentile(df['sqft_lot'], 99))
plt.show()

# %%
# Create boxplot for sqft_lot
_ = sns.boxplot(x='sqft_lot', data=df)
plt.show()

# %%
# Plot sqft_lot15 histogram
_ = sns.histplot(data=df, x='sqft_lot15')
plt.show()

# %%
# Plot sqft_lot15 histogram limited to 99th percentile
_ = sns.histplot(data=df, x='sqft_lot15')
plt.xlim(0,np.percentile(df['sqft_lot15'], 99))
plt.show()

# %%
# Create boxplot for sqft_lot15
_ = sns.boxplot(x='sqft_lot15', data=df)
plt.show()

# %%
# Plot sqft_above histogram
_ = sns.histplot(data=df, x='sqft_above')
plt.show()

# %%
# Create boxplot for sqft_above
_ = sns.boxplot(x='sqft_above', data=df)
plt.show()

# %% [markdown]
# sqft_above is right-skewed and has a wider IQR than sqft_living.

# %%
# Plot sqft_basement histogram
_ = sns.histplot(data=df, x='sqft_basement')
plt.show()

# %%
# Plot counts of basement area where sqft_basement value != 0
df_base = df[df['sqft_basement'] != 0]
sns.histplot(data=df_base, x='sqft_basement')
plt.show()

# %% [markdown]
# Many homes do not have basements as indicated by the high counts of 0 for sqft_basement.

# %%
# Plot counts of bedrooms
_ = sns.countplot(data=df, x='bedrooms')
plt.show()

# %%
# Create boxplot for bedrooms
_ = sns.boxplot(x='bedrooms', data=df)

# %%
# Find 99.99th percentile for bedrooms
np.percentile(df['bedrooms'], 99.99)
# Out:
# 10.0

# %% [markdown]
# **33 bedrooms is a conspicuous outlier that lies outside of the 99.99th percentile. Perhaps this is a motel or some type of multi-family dwelling? This will likely be removed in the future.**

# %%
# Plot counts of bathrooms
_ = sns.countplot(data=df, x='bathrooms')
plt.xticks(rotation=90)
plt.show()

# %%
# Create boxplot for bathrooms
_ = sns.boxplot(x='bathrooms', data=df)

# %%
np.percentile(df['bathrooms'], 99.99)
# Out:
# 7.70969999999943

# %% [markdown]
# The bathrooms distribution is bimodal, with many homes having only 1 bathroom. 2.5 bathrooms is the most common value for all homes.

# %%
# Plot counts of floors
_ = sns.countplot(data=df, x='floors')
plt.show()

# %% [markdown]
# Most homes have 1 or 2 floors.

# %%
# Plot counts of waterfront
_ = sns.countplot(data=df, x='waterfront')
plt.show()

# %%
df['waterfront'].value_counts()
# Out:
# 0    21450
# 1      163
# Name: waterfront, dtype: int64

# %% [markdown]
# Only 163 homes are waterfront properties.

# %%
# Plot counts of view
_ = sns.countplot(data=df, x='view')
plt.show()

# %% [markdown]
# Most homes have a 'view' value of 0.

# %%
# Plot counts of condition
_ = sns.countplot(data=df, x='condition')
plt.show()

# %% [markdown]
# Most homes have a condition value of 3.

# %%
# Plot counts of grade
_ = sns.countplot(data=df, x='grade')
plt.show()

# %% [markdown]
# Most homes have a grade value of 7 or 8. The distribution is slightly right-skewed.

# %%
# Plot counts of yr_built
_ = sns.histplot(data=df, x='yr_built')
plt.show()

# %%
# Plot counts of year renovated where yr_renovated != 0
df_reno = df[df['yr_renovated'] != 0]
_ = sns.histplot(data=df_reno, x='yr_renovated')
plt.show()

# %% [markdown]
# Of homes that were renovated, the distribution is left-skewed with increasing numbers of renovations in recent years.

# %%
# Plot counts of zipcode
_ = sns.histplot(data=df, x='zipcode', bins=df['zipcode'].nunique())
plt.xticks(rotation=90)
plt.show()

# %%
# Plot counts of lat
_ = sns.histplot(data=df, x='lat')
plt.xticks(rotation=90)
plt.show()

# %%
# Plot counts of long
_ = sns.histplot(data=df, x='long')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# zipcode, lat, and long are related geographic variables. Some areas had more home sales than others.

# %% [markdown]
# ## Bivariate plots of price vs. other features

# %%
# Generate pairplots with price on y-axis
_ = sns.pairplot(data=df, y_vars='price', x_vars=df.columns[1:8], height=2)
_ = sns.pairplot(data=df, y_vars='price', x_vars=df.columns[8:14], height=2)
_ = sns.pairplot(data=df, y_vars='price', x_vars=df.columns[14:], height=2)
plt.show()

# %% [markdown]
# - There appear to be linear trends between price and bedrooms, bathrooms, sqft_living, sqft_above, sqft_basement, sqft_living15.
#
# - Non-linear correlations with price include sqft_lot, sqft_lot15, grade, lat, long.

# %%
# Use pandas method .corr() to calculate the Pearson correlation coefficients
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
# Generate heatmap showing Pearson correlation coefficients
fig, ax = plt.subplots(figsize=(15, 9))
sns.set(font_scale=1)
_ = sns.heatmap(data=df.corr(), annot=True, linewidths=0.5, cmap='vlag', fmt='0.2f').set(title='Correlation Heatmap')
plt.show()

# %% [markdown]
# - sqft_living, grade, sqft_above, sqft_living15, bathrooms are the highest correlated features with price.
#
# - sqft_lot and sqft_lot15 do not appear to have linear relationships with price.
#
# - Many features are correlated with one another.
#
# - bedrooms has a low to moderate correlation with price. An outlier of 33 bedrooms and a relatively low price appears to be skewing the correlation. Removal of outliers or zeroes will likely result in higher correlations for other features such as sqft_basement, yr_renovated.
